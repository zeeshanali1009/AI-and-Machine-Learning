# %% [markdown]
# # **Hope to Skills - Advance AI Course**
# ## **Python Basics - Lecture 09 - Operators in Python**
#
# This note book cover the following concepts
# 1. Arithmetic Operators
# 2. Logical Operators

# %% [markdown]
# # **RECAP**
# # **Difference between List, Tuple, Sets and Dictionay**

# %% [markdown]
# ![difference details.png](data:image/png;base64,...)

# %% [markdown]
# ![difference .png](data:image/png;base64,...)

# %% [markdown]
# ## **What are Operators?**
#
# Python operators are symbols that perform an operation on one or more operands. An operand is a variable or a value on which we perform the operation

# %% [markdown]
# ## **Why use Operators?**
#
# Operators can manipulate individual items and return a result. Operators manipulate individual items by conducting mathematical operations and/or returning a Boolean value (True or False)

# %% [markdown]
# ## **What are Mathematical Operators?**
#
#
# Mathematical Operators are basic arithmetic symbol used to perform adition, subtraction, multiplication, and more

# %% [markdown]
# Mathematical operators are basic arithmetic symbols used to perform addition, subtraction, multiplication, and more.
#
# |Operator                  |Description                                                                        |Example |
# |-------------------------|-------------------------------------------------------------------------------|-------------|
# |Assignment (=)        |Assigns a variable a value. |(x = 5)       |
# |+       | Addition.                   |(1 + 2) |
# |-         | Subtraction. | (2 - 1)
# |* | Multiplication. |(1 * 2) |
# |/             |Division. |(10 / 5)|
# |% | Modulus. |(15 % 2)

# %% [markdown]
# ## **Operators on Numbers**
#
# Numerical operations in Python are similar to Excel or any other programming language.
# You can use these operations to do basic arithmetic

# %%
# Multiply two numbers and display using print
# print(3*4)
3*4
# Out:
# 12

# %%
# Display calculate square of number
print(3**2)
# Out:
# 9

# %%
# Calculate the Remainder
print(16%5)
# Out:
# 1

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Divide two numbers
a = 5.0/10.0
a
# Out:
# 0.5

# %%
# Calculate the Quotient of two numbers
b= 11//4
b
# Out:
# 2

# %% [markdown]
# ### Adding two integers

# %%
# Assigning a value of 5 to the variable num1
num1 = 5

# Assigning a value of 2 to the variable num2
num2 = 2

# Calculating the sum of num1 and num2 and storing it in the variable 'sum'
sum = num1 + num2

# Printing the calculated sum
print(sum)
# Out:
# 7

# %% [markdown]
# ## simple program to calculate the area of Rectangle
# area of rectangle = length * height

# %%
# Defining the length of the rectangle
length = 2.5

# Defining the height of the rectangle
height = 3.5

# Calculating the area of the rectangle using length and height
area = length * height

# Printing the calculated area of the rectangle
print(area)
# Out:
# 8.75

# %% [markdown]
# Comparison operators are used to compare values, they either return True or False.
#
# |Operator                  |Description                                                                        |Example |
# |-------------------------|-------------------------------------------------------------------------------|-------------|
# |Equal to (==)        |If the values of the two operands are equal, then the condition becomes true. |(a == a) is True.       |
# |Not Equal to (!=)       |If the values of the two operands are not equal, then the condition becomes true.                    |(a != b) is True.|
# |Greater Than, Greater than or Equal to (>, >=)          |If the value of the left operand is greater than the value of the right operand then the condition becomes true. | (2>1) is True.
# |Less Than, Less than or Equal to (<, <=) |If the value of the left operand is less than the value of the right operand then the condition becomes true. |(1<2) is True.|
# |and              |Returns True if all statements are True. |(1<2 and 2>1) is True.|
# |or | Returns True if one of the statements is True. |(1<2 or 2<4) is True.
# |not | Reverse the result, returns False if the statement is True.| not(1<5 and 5>3) is not True.

# %%
# Assigning a value of 330 to variable a
a = 330

# Assigning a value of 200 to variable b
b = 200

# Checking if a is equal to b using the equality operator (==)
# The result of this comparison will be False since a (330) is not equal to b (200)
result = a == b

# Printing the result of the comparison
print("Is a equal to b?", result)
# Out:
# Is a equal to b? False

# %%
# Checking if a is not equal to b using the inequality operator (!=)
# The result of this comparison will be True since a (330) is not equal to b (200)
result = a != b

# Printing the result of the comparison
print("Is a not equal to b?", result)
# Out:
# Is a not equal to b? True

# %%
# Checking if a is greater than b using the greater than operator (>)
# The result of this comparison will be True since a (330) is greater than b (200)
result = a > b
# Out:
# True

# %%
# Checking if a is greater than b using the greater than operator (>)
# The result of this comparison will be True since a (330) is greater than b (200)
result = a < b

# Printing the result of the comparison
print("Is a greater than b?", result)
# Out:
# False

# %%
a >= b
# Out:
# True

# %%
a <= b
# Out:
# False

# %%
a > 7
# Out:
# True

# %% [markdown]
# # **Logical Operators**
#
#
# AND
# OR
# NOT

# %%
a > b and a < 5
# Out:
# False

# %%
a > b or a < 5
# Out:
# True

# %% [markdown]
# ## not reverses the result, meaning it returns True if the statement is False.

# %%
not(1>2 and 3==4)
# Out:
# True

# %% [markdown]
# #### What are Membership Operators?####
#
# Membership operators are used to test whether a value or a variable is found in a sequence (string, tuple, list, set or dictionary). These operators become essential when we discuss loops.
#
# |Operator                  |Description                                                                        |Example |
# |-------------------------|-------------------------------------------------------------------------------|-------------|
# |in| Returns True if a sequence with the specified value is present in the object. | 3 in [1,2,3] is True.
# |not in| Returns True if a sequence with the specified value is not present in the object. | 4 not in [1,2,3] is True.

# %% [markdown]
# ## in returns True if a sequence with the specified value is present in the object.

# %%
'cat' in ['dog','cat','mouse']
# Out:
# True

# %% [markdown]
# ## not in returns True if a sequence with the specified value is not present in the object.

# %%
'geese' not in ['dog','cat','mouse']
# Out:
# True

# %% [markdown]
# ## **Operators on Strings**
#
# we can also use these operators on strings

# %% [markdown]
# The Addition sign (+) will concatenate a string

# %%
sentence = 'Hello' + ' ' + 'World'
print(sentence)
# Out:
# Hello World

# %%
k = 'Ha'
print(k * 5 + '!')
# Out:
# HaHaHaHaHa!!!!!

# %% [markdown]
# You can also use the double equal sign (==) to check if two strings are identical.

# %%
'ABCD' == 'ABCE'
# Out:
# False

# %% [markdown]
# ##  > and < will check if one string has more characters than the other

# %%
'1234567' > '12345'
# Out:
# True

# %% [markdown]
# The double equal sign is case sensitive

# %%
'ABC' == 'ABc'
# Out:
# False

# %% [markdown]
# Practice the concpet and Explore the python Language
#
#
# Assignment will be shared soon
